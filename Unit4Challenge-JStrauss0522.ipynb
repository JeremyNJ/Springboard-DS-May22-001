# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import numpy as np
import pandas as pd
# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %% [markdown]
# <p style="border:3px; border-style:solid; border-color:#FF0000; padding: 1em;"><b>Grader:</b> Please note that much of my output in this notebook was produced by print
# statements in the Python code. This output appears before each section's
# featured table or chart. Please consider these printouts an integral part of this notebook.</p>

# %%
# I used the following while exploring the data, and to test the results of my data tidying steps.
#properties.shape
#properties.columns
#properties.index
#properties.tail()
#properties.dtypes
#len(properties.iloc[:,0]) compared with len(properties.iloc[:,0].drop_duplicates())
print("Note that much of my analysis during initial cleaning and exploration was done on the fly.")
print("I used the following, throughout:")
print(".shape\n.columns\n.index\n.tail()\n.dtypes\n")
print("These steps were for my own benefit and were not included in the final notebook")
print("***Grader Please Note: much of my results output in this notebook was produced by print")
print("statements in the Python code. Please be sure to read output (like this note) that appears")
print("before each section's featured table or chart.")
print("\nCheck for duplicate date entries:")
print("len(properties.iloc[:,0]):", len(properties.iloc[:,0]))
print("len(properties.iloc[:,0].drop_duplicates()):", len(properties.iloc[:,0].drop_duplicates()))
print("\nproperties.head():\n")
properties.head()
# Out:
# Note that much of my analysis during initial cleaning and exploration was done on the fly.
# I used the following, throughout:
# .shape
# .columns
# .index
# .tail()
# .dtypes
#
# These steps were for my own benefit and were not included in the final notebook
# ***Grader Please Note: much of my results output in this notebook was produced by print
# statements in the Python code. Please be sure to read output (like this note) that appears
# before each section's featured table or chart.
#
# Check for duplicate date entries:
# len(properties.iloc[:,0]): 330
# len(properties.iloc[:,0].drop_duplicates()): 330
#
# properties.head():
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
# Transpose the df so the dates are the columns ("variables") and the boroughs are the rows
# ("observations")
txp=properties.transpose()
 #txp.shape
 #txp.head()

# Drop the first column, which was the first row, and was some sort of id for the geographic regions.
txp2=txp.drop(0, axis='columns')
print("txp2.index:\n", txp2.index)

# Set the first row (the dates of each observation) as the header, and remove it from the data rows
txp2.columns = txp2.iloc[0]
txp2 = txp2[1:]

# Retain only the rows which are boroughs of London. (We also retain City of London, a non-borough
# government district, for now, to see if including it in the analysis may be interesting.
# Like the boroughs, it is a government district with housing statistics. Excluding it from
# this analysis seems a bit arbitrary.
txp3 = txp2[0:33]
print("\nHere is the transposed dataframe. The first row (the dates) is now column labels.")
print("Only the rows representing the boroughs of London are retained, with the addition")
print("of City of London, a non-borough government entity, which may be of interest.")
txp3.head()
# Out:
# txp2.index:
#  Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')
#
# Here is the transposed dataframe. The first row (the dates) is now column labels.
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
# Let's make the names of the boroughs a regular data variable (ie column) and create
# a new column with uniform substrings of the borough names, for easier reference.
# (There is no point making the new column an index, because we will be stacking the data
# to make a long DataFrame, and the boroughs will no longer be unique.)
txp4 = txp3.reset_index()
txp4.rename(columns={"index": "borough"}, inplace=True)
txp4['keyname'] = txp4['borough'].apply(lambda s : s[0:4])
print("col keyname is unique:", txp4['keyname'].is_unique)
#txp4.set_index('keyname', inplace=True)
print("Show renamed borough column.")
print("Note new column at the end with substrings of borough name, for easier reference.")
txp4.head()
# Out:
# col keyname is unique: True
# Show renamed borough column.
# Note new column at the end with substrings of borough name, for easier reference.
# Unnamed: 0             borough 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 0               City of London         91448.98487         82202.77314
# 1           Barking & Dagenham          50460.2266         51085.77983
# 2                       Barnet         93284.51832         93190.16963
# 3                       Bexley         64958.09036         64787.92069
# 4                        Brent         71306.56698         72022.26197
#
# Unnamed: 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 0                  79120.70256         77101.20804         84409.14932
# 1                  51268.96956         53133.50526         53042.24852
# 2                  92247.52435         90762.87492         90258.00033
# 3                  64367.49344         64277.66881         63997.13588
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
# We will look at the most recent 20 full calendar years, 2002 through 2021. And to look at those
# years, comparing price change over time by borough, we do not need to be concerned with the
# little ups and downs every month. So we will be summarizing each year with an annual average
# by borough, later in this series of data manipulations.
# For now, let's start by stacking the most recent 20 years:
long_df = txp4.melt(id_vars=['borough', 'keyname'], value_vars=txp4.columns[85:325],
                    var_name=['date'], value_name='price')
print("long_df.shape:", long_df.shape)
print("long_df.head():\n", long_df.head())
print("\nlong_df.tail():")
long_df.tail()
# Out:
# long_df.shape: (7920, 4)
# long_df.head():
#                borough keyname       date        price
# 0      City of London    City 2002-01-01  344238.8808
# 1  Barking & Dagenham    Bark 2002-01-01  98713.31808
# 2              Barnet    Barn 2002-01-01  203249.2538
# 3              Bexley    Bexl 2002-01-01   124283.022
# 4               Brent    Bren 2002-01-01   168670.917
#
# long_df.tail():
#              borough keyname       date        price
# 7915          Sutton    Sutt 2021-12-01   410206.777
# 7916   Tower Hamlets    Towe 2021-12-01  440311.3435
# 7917  Waltham Forest    Walt 2021-12-01  473703.1011
# 7918      Wandsworth    Wand 2021-12-01  642082.9944
# 7919     Westminster    West 2021-12-01  1049442.911

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
print('dtypes:')
long_df.dtypes
# Out:
# dtypes:
# borough            object
# keyname            object
# date       datetime64[ns]
# price              object
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
print("Check equal column lengths:")
for col in long_df.columns : print("len("+col+"):", len(long_df[col]))
# unique boroughs should be 33 (32 boroughs + City of London)
print("\nunique boroughs (should be 33 incl City):", len(set(long_df.loc[:,'borough'])))
# Section 2.4, above, revealed unexpected data types. Let's see if the problem is nulls.
print("\ncheck for nulls:")
for col in long_df.columns : print("isna("+col+").sum:", pd.isna(long_df[col]).sum())
# Out:
# Check equal column lengths:
# len(borough): 7920
# len(keyname): 7920
# len(date): 7920
# len(price): 7920
#
# unique boroughs (should be 33 incl City): 33
#
# check for nulls:
# isna(borough).sum: 0
# isna(keyname).sum: 0
# isna(date).sum: 0
# isna(price).sum: 0

# %%
# There are no nulls. Let's take a closer look at type for the prices
count = 0
for ind, val in enumerate(long_df['price']) :
    if type(val) == type(1.0) : count += 1
    else : print("price", ind, "type:", type(val))
print("float:", count)
# Out:
# price 2296 type: <class 'int'>
# float: 7919

# %%
# That's easy to fix.
count = 0
fixed = 0
for ind, val in enumerate(long_df['price']) :
    if type(val) == type(1.0) :
        count += 1
    elif type(val) == type(1) :
        print('price at', ind, "was", long_df.loc[long_df.index[ind], 'price'])
        long_df.loc[long_df.index[ind], 'price'] = float(val)
        print('price at', ind, "is now", long_df.loc[long_df.index[ind], 'price'])
        fixed += 1
print("float:", count)
print("fixed:", fixed)
# Out:
# price at 2296 was 808270
# price at 2296 is now 808270.0
# float: 7919
# fixed: 1

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
# Let's begin exploring the data with a quick look at the boroughs with the lowest prices
# and those with the highest prices. We'll take a glance at the beginning of our 20-year
# study period in 2002 and at the end in 2021. and chart the prices
# To get a feel for price increases over time, we will plot prices over time for the 3
# boroughs with the highest ending prices.
print("Lowest prices at the beginning of the 20-year period:\n")
print(long_df[long_df['date']==datetime(2002, 1, 1, 0, 0)].sort_values('price').head(10))
print("\nHighest prices at the beginning:\n")
print(long_df[long_df['date']==datetime(2002, 1, 1, 0, 0)].sort_values('price',
                                                                      ascending=False).head(10))
print("\nLowest prices at the end:\n")
print(long_df[long_df['date']==datetime(2021, 12, 1, 0, 0)].sort_values('price').head(10))
print("\nHighest prices Dec, 2021, at the end of 20-year study period:")
long_df[long_df['date']==datetime(2021, 12, 1, 0, 0)].sort_values('price',
                                                                       ascending=False).head(10)
# Out:
# Lowest prices at the beginning of the 20-year period:
#
#                borough keyname       date        price
# 1   Barking & Dagenham    Bark 2002-01-01  98713.31808
# 24              Newham    Newh 2002-01-01   122669.364
# 3               Bexley    Bexl 2002-01-01   124283.022
# 22            Lewisham    Lewi 2002-01-01  131762.7235
# 15            Havering    Have 2002-01-01  132721.0876
# 30      Waltham Forest    Walt 2002-01-01  132998.5882
# 10           Greenwich    Gree 2002-01-01   134327.355
# 7              Croydon    Croy 2002-01-01  143107.5277
# 9              Enfield    Enfi 2002-01-01  144678.1943
# 28              Sutton    Sutt 2002-01-01  149153.1144
#
# Highest prices at the beginning:
#
#                  borough keyname       date        price
# 19  Kensington & Chelsea    Kens 2002-01-01  407491.9055
# 0         City of London    City 2002-01-01  344238.8808
# 32           Westminster    West 2002-01-01  304679.0659
# ...

# %%
# To take the 3 boroughs with highest prices at the end of 2021 and plot them over time, together,
# we need 3 arrays or one DataFrame with 3 columns. I will create the one DataFrams by subsetting
# long_df on the 3 different boroughs and then merging the results:
df_kens = long_df.loc[:, 'keyname':'price'].query("keyname == 'Kens'")
df_west = long_df.loc[:, 'keyname':'price'].query("keyname == 'West'")
df_camd = long_df.loc[:, 'keyname':'price'].query("keyname == 'Camd'")
df3 = df_kens.merge(df_west, on='date', suffixes=('','_west'))\
             .merge(df_camd, on='date', suffixes=('_kens','_camd'))
print('df3 shape:', df3.shape)
print(df3.head())
df3.plot(x="date", y=["price_kens", "price_west", "price_camd"],
            kind="line", rot=90, ylabel="price",
            label=['Kens & Chelsea','Westminster','Camden'])
# Out:
# df3 shape: (240, 7)
#   keyname_kens       date   price_kens keyname_west   price_west keyname_camd  \
# 0         Kens 2002-01-01  407491.9055         West  304679.0659         Camd
# 1         Kens 2002-02-01  406516.1073         West  314894.6935         Camd
# 2         Kens 2002-03-01  414375.7153         West  312816.5267         Camd
# 3         Kens 2002-04-01  440746.3695         West  325625.8694         Camd
# 4         Kens 2002-05-01  467440.5725         West  331670.2029         Camd
#
#     price_camd
# 0  290461.3455
# 1  289269.8819
# 2  289614.8718
# 3  296978.9435
# 4  308913.2816
# <AxesSubplot:xlabel='date', ylabel='price'>

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# Add new column for year
long_df['year'] = long_df['date'].apply(lambda d : d.year)
print("long_df.tail showing new column for year")
print(long_df.tail())
print()

# Summarize by borough/year
# Note that .groupby() returns a pandas series and we want a DataFrame
df_years = pd.DataFrame(long_df.groupby(["borough", "year"])["price"].mean())
df_years.reset_index(inplace=True)
df_years.rename(columns={'price': 'mean_price_for_year'}, inplace=True)
#for i in df_years.columns : print("col name:", i)
print("df_years.head showing new DataFrame boiling the data down to one average for each year")
print(df_years.head())
print()
print("df_years.tail")
print("32 boroughs + City of London = 33 x 20 years makes 660 rows\n")
print(df_years.tail())
# Out:
# long_df.tail showing new column for year
#              borough keyname       date        price  year
# 7915          Sutton    Sutt 2021-12-01   410206.777  2021
# 7916   Tower Hamlets    Towe 2021-12-01  440311.3435  2021
# 7917  Waltham Forest    Walt 2021-12-01  473703.1011  2021
# 7918      Wandsworth    Wand 2021-12-01  642082.9944  2021
# 7919     Westminster    West 2021-12-01  1049442.911  2021
#
# df_years.head showing new DataFrame boiling the data down to one average for each year
#               borough  year  mean_price_for_year
# 0  Barking & Dagenham  2002        112221.912482
# 1  Barking & Dagenham  2003        142498.927800
# 2  Barking & Dagenham  2004        158175.982483
# 3  Barking & Dagenham  2005        163360.782017
# 4  Barking & Dagenham  2006        167853.342558
#
# df_years.tail
# 32 boroughs + City of London = 33 x 20 years makes 660 rows
#
#          borough  year  mean_price_for_year
# 655  Westminster  2017         1.064772e+06
# ...

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
# Let's get that growth rate. Rather than the suggested ratio of 2021 price over
# 2002 price, we calculate an actual growth rate: growth / original.
# We'll pull out 2002 and 2021 and create a new column for growth.
#
# (NOTE: A more sophisticated analysis of price increases would look at year-over-year
# per-cent increases. These could be compared across boroughs graphically, or boiled down
# to a single statistic: a mean of the 19 year-over-year per-cent increases for each borough.)
#
df_increase = df_years.query("year == 2002 or year == 2021")
print("Before pivot, df_increase.shape:", df_increase.shape)
print("Before pivot, df_increase.head:\n")
print(df_increase.head(), '\n')
df_increase = df_increase.pivot(index="borough", columns="year")
print("After pivot, df_increase.shape", df_increase.shape)
print("After pivot, df_increase.head:\n")
print(df_increase.head())
df_increase.columns = ['2002', '2021']
# create new columns
df_increase['growth_rate'] = (df_increase['2021'] - df_increase['2002']) / df_increase['2002']
print("\nLondon boroughs, (plus City of London, an interesting non-borough entity).")
print("Sorted by growth rate. Here are the top 15:")
print("Note that I have calculated an actual growth rate (end - start)/start")
print(df_increase.sort_values('growth_rate', ascending=False).head(15))
df_increase['end_over_start'] = df_increase['2021'] / df_increase['2002']
df_increase['start_over_end'] = df_increase['2002'] / df_increase['2021']
print("\nLondon boroughs, (plus City of London, an interesting non-borough entity).")
print("Sorted by the end/start ratio. Here are the top 5:")
print("Note that I have also calculated the reciprocal of the brief's suggested start/end ratio,")
print("ratio, a better statistic because higher numbers denote higher growth.")
df_increase.sort_values('end_over_start', ascending=False).head()
# Out:
# Before pivot, df_increase.shape: (66, 3)
# Before pivot, df_increase.head:
#
#                borough  year  mean_price_for_year
# 0   Barking & Dagenham  2002        112221.912482
# 19  Barking & Dagenham  2021        316507.833575
# 20              Barnet  2002        220746.059225
# 39              Barnet  2021        550728.768792
# 40              Bexley  2002        136797.964475
#
# After pivot, df_increase.shape (33, 2)
# After pivot, df_increase.head:
#
#                    mean_price_for_year
# year                              2002           2021
# borough
# Barking & Dagenham       112221.912482  316507.833575
# Barnet                   220746.059225  550728.768792
# Bexley                   136797.964475  366009.711992
# Brent                    185898.147992  513736.526025
# Bromley                  186646.043217  465972.077350
#
# London boroughs, (plus City of London, an interesting non-borough entity).
# Sorted by growth rate. Here are the top 15:
# ...

# %%
# provide a bar chart of the growth leaders
df_bar=df_increase.sort_values('end_over_start', ascending=False)
df_bar=df_bar.iloc[0:15]
df_bar.plot(y="growth_rate", kind="bar", rot=90, ylabel="price growth rate", figsize=(10, 4))
# Out:
# <AxesSubplot:xlabel='borough', ylabel='price growth rate'>

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# # London Boroughs Housing Prices
#   The instructions at the beginning of this notebook ask for an analysis of which boroughs of
# London have seen the greatest increase in housing prices over the last two decades. I have
# abridged the data to the most recent 20 full calendar years, 2002-2021.
#
#   Guidance in step 3 suggests creating a ratio, for each borough, of average prices for the
# oldest year over the most recent year. I have provided that, but first I developed
# two statistics for growth that I believe are more useful.
#   Let's call the oldest year in the past 20, the "origin" year, and the most recent
# the "latest" year. Here are the two statistics I developed:
#
#   1. An actual growth rate: difference / origin<br>
#      (where "difference" is: latest less origin).<br>
#      This has the advantage of being a statistic that economists and social scientists would
#      recognize. It also has the benefit of having a basis at zero, whereby a positive result
#      denotes positive growth and a negative result denotes negative growth.
#   2. The reciprocal of the ratio suggested by the brief's guidance, ie latest / origin
#      (rather than the suggested origin / latest).
#      Though this does not have a basis of 0, (zero growth instead has a ratio of 1) it has the
#      advantage of varying with growth: higher ratios represent greater growth.
#
#   Ranking both of these growth statistics in descending order reveals a top 3:
#   - Hackney
#   - Waltham Forest
#   - Lewisham<br>
# Because we focused on growth, we have found boroughs remarkable not for achieving high current
# values, but rather for having lower original prices. Higher price growth in Waltham Forest and
# Lewisham, in particular, has propelled those two boroughs out of the bottom ranks in housing
# prices. (Hackney did not start in the bottom ranks, and thanks to stronger growth, ended in the
# top 10.)
#
#   One must not read too much into this growth-rate comparison. Many districts had similar high growth in prices. In particular, note that the districts that had the highest prices in 2002 had strong growth as well, as shown in the
# chart in section 2.6. The districts with the highest prices in 2002 remained the districts with the highest prices in 2021. It can be
# presumed that someone who owned a home in one of those pricier districts in 2002 was not
# regretting their investment or wishing they lived in Hackney.
#
#   Our focus on growth, however, has narrowed our attention not on the districts with highest
# prices, but rather on those with greatest growth: Hackney, Waltham Forest, and
# Lewisham. Those interested solely in growth (real estate speculators, for example) who were
# invested in those 3 boroughs saw those investments achieve greater growth.
#
#   Looking forward, one would need to study demographic trends to
# decide whether real estate in Hackney, Waltham Forest, and Lewisham remains a good investment.
# But these boroughs' housing prices are still lower than the priciest boroughs plotted in step 2.6. Investments in Hackney, Waltham Forest, and Lewisham may have room for additional appreciation.
